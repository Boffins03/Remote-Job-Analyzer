# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
remoteok = pd.read_csv("jobs_remoteok.csv")

# %%
remotely = pd.read_csv("jobs_weworkremotely.csv")

# %%
wellfound = pd.read_csv("jobs_wellfound.csv")

# %%
remoteok.head()
# Out:
#                                      title            company  \
# 0                             Job openings  Anchorage Digital
# 1      Financial Copyeditor & Fact Checker    The Motley Fool
# 2                 Sales Operations Analyst            Hometap
# 3             Information Security Analyst              Monzo
# 4  Patient Engagement Specialist Temporary    Sprinter Health
#
#                 location          salary  \
# 0                 Remote  60000 - 120000
# 1          United States           0 - 0
# 2                 Remote   60000 - 90000
# 3  Cardiff London or  UK   40000 - 50000
# 4                 Remote           0 - 0
#
#                                           apply_link
# 0  https://remoteOK.com/remote-jobs/remote-job-op...
# 1  https://remoteOK.com/remote-jobs/remote-financ...
# 2  https://remoteOK.com/remote-jobs/remote-sales-...
# 3  https://remoteOK.com/remote-jobs/remote-inform...
# 4  https://remoteOK.com/remote-jobs/remote-patien...

# %%
wellfound.head()
# Out:
#                                                title    company  \
# 0  Software Engineer, Platform (Developer Experie...  Benchling
# 1                             Implementation Manager  Benchling
# 2                           Product Support Engineer  YipitData
# 3                                       Data QA Lead  YipitData
# 4                  Solutions Architect, Integrations  YipitData
#
#                                details  \
# 0  $141k – $191kRemote • San Francisco
# 1          Onsite or remote • London+1
# 2                        $115k – $130k
# 3                          $20k – $70k
# 4                        $120k – $130k
#
#                                           apply_link
# 0  https://wellfound.com//jobs/3511585-software-e...
# 1  https://wellfound.com//jobs/3511400-implementa...
# 2  https://wellfound.com//jobs/3503322-product-su...
# 3   https://wellfound.com//jobs/3502467-data-qa-lead
# 4  https://wellfound.com//jobs/3493696-solutions-...

# %%
remotely.head()
# Out:
#                                                title    company  \
# 0                       Full Stack Developer (m/f/d)  SocialHub
# 1  Full-Stack Developer (TypeScript/Next.js • Cloud)    VidRush
# 2                                     Technical Lead     Walter
# 3                                 Fullstack Engineer     Contra
# 4                   Coding bootcamp - Job Guaranteed     Metana
#
#                                             location  categories  \
# 0  Schütterlettenweg 4, 85053 Ingolstadt, Deutsch...         NaN
# 1                                                 UK         NaN
# 2                                             Remote         NaN
# 3                                  San Francisco, CA         NaN
# 4  Learn job-ready skills on your schedule with 1...         NaN
#
#                                           apply_link
# 0  https://weworkremotely.com/remote-jobs/socialh...
# 1  https://weworkremotely.com/remote-jobs/vidrush...
# 2  https://weworkremotely.com/remote-jobs/walter-...
# 3  https://weworkremotely.com/remote-jobs/contra-...
# 4  https://weworkremotely.comhttps://link.metana....

# %%
remotely.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       314 non-null    object
#  1   company     314 non-null    object
#  2   location    306 non-null    object
#  3   categories  0 non-null      float64
#  4   apply_link  320 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 12.6+ KB
